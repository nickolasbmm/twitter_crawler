# %%
import tweepy
from secrets import bearer_token, consumer_key,consumer_secret,access_token,access_token_secret
import pandas as pd
import glob
import os
pd.options.display.max_columns = 200
from math import inf
client = tweepy.Client(bearer_token, consumer_key,consumer_secret,access_token,access_token_secret,wait_on_rate_limit=True)

# %%
def get_tweets(query,df,num_tweets=inf,start_token=""):

    # Searches for a maximum of "num_tweets" tweets
    # If num_tweets = inf, gets all tweets available
    # Partial results are saved in temp/ folder
    df = pd.DataFrame()
    # max_results = 10
    max_results = 500
    if num_tweets == inf:
        total_pages = inf
    else:
        total_pages = round(num_tweets/max_results)
    num_pages = 0
    token = start_token

    while num_pages < total_pages:
        print(f"Page number {num_pages} starting")
        if token == "":
            page = client.search_all_tweets(query,
                                            max_results=max_results,
                                            tweet_fields=["created_at","author_id","referenced_tweets"],
                                            user_fields=["created_at"],
                                            expansions=["referenced_tweets.id,author_id,referenced_tweets.id.author_id"])
        else:
            page = client.search_all_tweets(query,
                                            max_results=max_results,
                                            next_token = token,
                                            tweet_fields=["created_at","author_id","referenced_tweets"],
                                            user_fields=["id","name","username","created_at"],
                                            expansions=["referenced_tweets.id,author_id,referenced_tweets.id.author_id"])

        try:
            page_df = pd.DataFrame(page.data)
            page_df.dropna()
            page_df["referenced_tweets_type"] = page_df["referenced_tweets"].apply(lambda x: x[0].type)
            page_df["referenced_tweets_id"] = page_df["referenced_tweets"].apply(lambda x: x[0].id)
            page_df = page_df[page_df.columns.intersection(["author_id","created_at","id","text","referenced_tweets_type","referenced_tweets_id"])]
            
            users_df = pd.DataFrame(page.includes["users"])
            users_df = users_df.rename(columns={"id":"author_id","created_at":"author_created_at","name":"author_name","username":"author_username"})
            users_df = users_df[users_df.columns.intersection(["author_id","author_created_at","author_name","author_username"])]

            
            ref_df = pd.DataFrame(page.includes["tweets"])
            ref_df = ref_df.merge(users_df)
            ref_df = ref_df.rename(columns={"id":"referenced_tweets_id","created_at":"referenced_tweets_created_at","author_id":"referenced_tweets_author_id","text":"referenced_tweets_text","author_created_at":"referenced_tweets_author_created_at","author_name":"referenced_tweets_author_name","author_username":"referenced_tweets_author_username"})
            ref_df = ref_df[ref_df.columns.intersection(["referenced_tweets_id","referenced_tweets_created_at","referenced_tweets_author_id","referenced_tweets_text","referenced_tweets_author_created_at","referenced_tweets_author_name","referenced_tweets_author_username"])]

            page_df = page_df.merge(users_df)
            page_df = page_df.merge(ref_df)
            
            df = df.append(page_df,ignore_index=True)
            if "next_token" in page.meta:
                token = page.meta["next_token"]
                page_df.to_csv(f"temp/{token}.csv")
                print(f"Page {num_pages} finished, next_token = {token}")
            else:
                print(f"Page {num_pages} finished. All tweets for this query collected.")
                page_df.to_csv(f"temp/end.csv")
                return df            
        except:
            if "next_token" in page.meta:
                token = page.meta["next_token"]
            else:
                print("No next_token column. All tweets for this query collected.")
                return df

            print(f"Page {num_pages} failed, next_token = {token}. Skipping")
        # sleep(0.1)
        num_pages+=1

    df.to_csv("retweets.csv")
    return df

# %%
df = pd.DataFrame()
df = get_tweets("(covid OR coronavirus OR corona OR covid-19) lang:pt is:retweet",df,4_000_000)
df
# Out:
# Page number 0 starting
# Page 0 finished, next_token = b26v89c19zqg8o3fpdv8qd8nho5el6xynlt9s9nnj3zwd
# Page number 1 starting
# Page 1 finished, next_token = b26v89c19zqg8o3fpdv8qd8n715jbmex4mphreldlyxz1
# Page number 2 starting
# Page 2 finished, next_token = b26v89c19zqg8o3fpdv8qd8chmt4ifznajcv1yfucpail
# Page number 3 starting
# Page 3 finished, next_token = b26v89c19zqg8o3fpdv8qd81qrc4pus17x9xhxsoy0mt9
# Page number 4 starting
# Page 4 finished, next_token = b26v89c19zqg8o3fpdv8qd7r2v6tul53ja4n8gduynlh9
# Page number 5 starting
# Page 5 finished, next_token = b26v89c19zqg8o3fpdv8qd7qtr0zrczkzg97jaxzdqqnx
# Page number 6 starting
# Page 6 finished, next_token = b26v89c19zqg8o3fpdv8qd7g5wl0rmttksd1c1lt1g29p
# Page number 7 starting
# Page 7 finished, next_token = b26v89c19zqg8o3fpdv8qd75gi8rcl10m95k0cij4vg59
# Page number 8 starting
# Page 8 finished, next_token = b26v89c19zqg8o3fpdv8qd6upla0yr7q40y2fq3dxenp9
# Page number 9 starting
# Page 9 finished, next_token = b26v89c19zqg8o3fpdv8qd6k07korzdv0ajk6li54tmyl
# Page number 10 starting
# Page 10 finished, next_token = b26v89c19zqg8o3fpdv8qd696a7pf4p1vget1mrxs0eil
# Page number 11 starting
# Page 11 finished, next_token = b26v89c19zqg8o3fpdv8qd5ycb5loz731kt6l08thburh
# Page number 12 starting
# Page 12 finished, next_token = b26v89c19zqg8o3fpdv8bqt8v36f3mflv7tl70of9g1h9
# Page number 13 starting
# Page 13 finished, next_token = b26v89c19zqg8o3fpdv8bqsy479uolku0jnse19hqphtp
# Page number 14 starting
# Page 14 finished, next_token = b26v89c19zqg8o3fpdv8bqsxs1v94okt4x3itot4jrxq5
# Page number 15 starting
# Page 15 finished, next_token = b26v89c19zqg8o3fpdv8bqsn2mo9lmvjgf0jw9ljh3x4t
# Page number 16 starting
# Page 16 finished, next_token = b26v89c19zqg8o3fpdv8bqs1se2bx3cf4fano52pzrtkt
# Page number 17 starting
# Page 17 finished, next_token = b26v89c19zqg8o3fpdv8bqrqwyidzupcpjbr2y3fgm931
# Page number 18 starting
# Page 18 finished, next_token = b26v89c19zqg8o3fpdv8bqrfyhi4dac6qjdclkwrarjwd
# Page number 19 starting
# Page 19 finished, next_token = b26v89c19zqg8o3fpdv8bqqui5jxjkpoahshny32a1b3x
# Page number 20 starting
# Page 20 finished, next_token = b26v89c19zqg8o3fpdv8bonx0c6112is3kujkods13zwd
# Page number 21 starting
# Page 21 finished, next_token = b26v89c19zqg8o3fpdv8bon0ihymk7ewo9zaq3o0wdshp
# Page number 22 starting
# Page 22 finished, next_token = b26v89c19zqg8o3fpdv8bomf0pbc4usef48mkwcf7g3nh
# Page number 23 starting
# Page 23 finished, next_token = b26v89c19zqg8o3fpdv8bom49sclqkkikqnqbxe8sy7i5
# Page number 24 starting
# Page 24 finished, next_token = b26v89c19zqg8o3fpdv8boltivt2z0p3d7j0qic28vtkt
# Page number 25 starting
# Page 25 finished, next_token = b26v89c19zqg8o3fpdv8bmjskf1jv448krezmnlhlpda5
# Page number 26 starting
# Page 26 finished, next_token = b26v89c19zqg8o3fpdv8bmjhrznvjupjgef276dfhhpj1
# Page number 27 starting
# Page 27 finished, next_token = b26v89c19zqg8o3fpdv8bmj714715zv88q4v2nxtemgzh
# Page number 28 starting
# Page 28 finished, next_token = b26v89c19zqg8o3fpdv8bmj6qhtytawdiafnxgb0alegt
# Page number 29 starting
# Page 29 finished, next_token = b26v89c19zqg8o3fpdv8bmiw139xmscd2dblvefn25bp9
# Page number 30 starting
# Page 30 finished, next_token = b26v89c19zqg8o3fpdv8bmild7rqixr5aniunrytjf725
# Page number 31 starting
# Page 31 finished, next_token = b26v89c19zqg8o3fpdv8bmil43e6urt1xb31t2aoan24d
# Page number 32 starting
# Page 32 finished, next_token = b26v89c19zqg8o3fpdv8bmiaj8pgc2oys2w1aw07a2071
# Page number 33 starting
# Page 33 finished, next_token = b26v89c19zqg8o3fpdv8bmiabnl9stuvds4xr6i1c7lh9
# Page number 34 starting
# Page 34 finished, next_token = b26v89c19zqg8o3fpdv8bmhzqswjaflgax4cq753hrfy5
# Page number 35 starting
# Page 35 finished, next_token = b26v89c19zqg8o3fpdv8bmhzj9hu3w9124i0cdz91r8n1
# Page number 36 starting
# Page 36 finished, next_token = b26v89c19zqg8o3fpdv8bmhoye60wyypqix3u1nxgiohp
# Page number 37 starting
# Page 37 finished, next_token = b26v89c19zqg8o3fpdv8bmhec0uwmxrxths1umjxcgm7x
# Page number 38 starting
# Page 38 finished, next_token = b26v89c19zqg8o3fpdv8bmhe2xc332o232iie455csad9
# Page number 39 starting
# Page 39 finished, next_token = b26v89c19zqg8o3fpdv8bmh3f34079w0ojyr69edsv4hp
# Page number 40 starting
# Page 40 finished, next_token = b26v89c19zqg8o3fpdv8bmh37gi46fuy0t2i895me9h8d
# Page number 41 starting
# Page 41 finished, next_token = b26v89c19zqg8o3fpdv8bkf2ajmypb11qaewrcs4rdx8d
# Page number 42 starting
# Page 42 finished, next_token = b26v89c19zqg8o3fpdv8bkero7lvet4v1w00krbcc7r0d
# Page number 43 starting
# Page 43 finished, next_token = b26v89c19zqg8o3fpdv8bkerglupia44765ywkjp8gtj1
# Page number 44 starting
# Page 44 finished, next_token = b26v89c19zqg8o3fpdv8bkegvqy52hk70krt57gnmi3r1
# Page number 45 starting
# Page 45 finished, next_token = b26v89c19zqg8o3fpdv8bkego69j6fplf8p8l0g346ohp
# Page number 46 starting
# Page 46 finished, next_token = b26v89c19zqg8o3fpdv8bke63cuwvxn37ccnowq4f3m2l
# Page number 47 starting
# Page 47 finished, next_token = b26v89c19zqg8o3fpdv8bke5vqw2fu91lgr6jdqd32zjx
# Page number 48 starting
# Page 48 finished, next_token = b26v89c19zqg8o3fpdv8bkdvax1xpql4mrkrmt8srkfb1
# Page number 49 starting
# Page 49 finished, next_token = b26v89c19zqg8o3fpdv8bkdv3bqcevputeqvlknw55svx
# Page number 50 starting
# Page 50 finished, next_token = b26v89c19zqg8o3fpdv8bkdkig6tmewvm345clfnv9jel
# Page number 51 starting
# Page 51 finished, next_token = b26v89c19zqg8o3fpdv8bkdkav2iszo4cczbc2d77mhdp
# Page number 52 starting
# Page 52 finished, next_token = b26v89c19zqg8o3fpdv8bkd9q10uynzg5qdvv0a6pmhz1
# Page number 53 starting
# Page 53 finished, next_token = b26v89c19zqg8o3fpdv8bkd9jyj6j2anz4sb1v7jkh8xp
# Page number 54 starting
# Page 54 finished, next_token = b26v89c19zqg8o3fpdv8bkd9dwgu3ejc196kv7tz05wu5
# Page number 55 starting
# Page 55 finished, next_token = b26v89c19zqg8o3fpdv8bkcyulojf2dbcl07brpptuem5
# Page number 56 starting
# Page 56 finished, next_token = b26v89c19zqg8o3fpdv8bkcyq0bsxyttm93tblw8thoql
# Page number 57 starting
# Page 57 finished, next_token = b26v89c19zqg8o3fpdv8bkco6oor2whdq9o50emv4jm9p
# Page number 58 starting
# Page 58 finished, next_token = b26v89c19zqg8o3fpdv8bkcnz3zzrt4tjahsjgil8kinx
# Page number 59 starting
# Page 59 finished, next_token = b26v89c19zqg8o3fpdv8bkcdeadoz3punxruzvxi7eoot
# Page number 60 starting
# Page 60 finished, next_token = b26v89c19zqg8o3fpdv8bkcd6p9lq6w2vw6y3dvvbfrlp
# Page number 61 starting
# Page 61 finished, next_token = b26v89c19zqg8o3fpdv8biaccscz7yyucqr87bjj8wf3x
# Page number 62 starting
# Page 62 finished, next_token = b26v89c19zqg8o3fpdv8biac58bcrmytai09xk5at7ddp
# Page number 63 starting
# Page 63 finished, next_token = b26v89c19zqg8o3fpdv8bia1ivfnp03dwstzjqdzwbq7x
# Page number 64 starting
# Page 64 finished, next_token = b26v89c19zqg8o3fpdv8bia19q76c69wub9mt93ucl3lp
# Page number 65 starting
# Page 65 finished, next_token = b26v89c19zqg8o3fpdv8bi9qluwmnhqdwzwimxwfhc4u5
# Page number 66 starting
# Page 66 finished, next_token = b26v89c19zqg8o3fpdv8bi9fwgs2v1wg2eth7ldugtawt
# Page number 67 starting
# Page 67 finished, next_token = b26v89c19zqg8o3fpdv8bi9542on4qwokzafz19qpfgql
# Page number 68 starting
# Page 68 finished, next_token = b26v89c19zqg8o3fpdv8bi8u71y1vipqw0g64xyx3t8xp
# Page number 69 starting
# Page 69 finished, next_token = b26v89c19zqg8o3fpdv8bi7n7fd7dkzi864qdffbgafel
# Page number 70 starting
# Page 70 finished, next_token = b26v89c19zqg8o3fpdv8bg50mlnge5e6hlqcrib3bfpfh
# Page number 71 starting
# Page 71 finished, next_token = b26v89c19zqg8o3fpdv8bg4po401y736nreyywv7kbjwd
# Page number 72 starting
# Page 72 finished, next_token = b26v89c19zqg8o3fpdv8bg4evphbbqsafxrhwxmlu369p
# Page number 73 starting
# Page 73 finished, next_token = b26v89c19zqg8o3fpdv8bg449by8srn0y2qe61i70fypp
# Page number 74 starting
# Page 74 finished, next_token = b26v89c19zqg8o3fpdv8bg4407d3ugaat6f7f63e0q1dp
# Page number 75 starting
# Page 75 finished, next_token = b26v89c19zqg8o3fpdv8bg3tduwmgd5zprs3ftlc3l56l
# Page number 76 starting
# Page 76 finished, next_token = b26v89c19zqg8o3fpdv8bg3t69si3t3o8jdhakovh4fb1
# Page number 77 starting
# Page 77 finished, next_token = b26v89c19zqg8o3fpdv8bg3imxiocmiffz4vijz9w0jnh
# Page number 78 starting
# Page 78 finished, next_token = b26v89c19zqg8o3fpdv8bg3igwxy866iq3csjcwyb0qkd
# Page number 79 starting
# Page 79 finished, next_token = b26v89c19zqg8o3fpdv8bg3icc0ebd9cq4gocixy9wltp
# Page number 80 starting
# Page 80 finished, next_token = b26v89c19zqg8o3fpdv8bg37rhyhsfqb47bo4kgilu5q5
# Page number 81 starting
# Page 81 finished, next_token = b26v89c19zqg8o3fpdv8bg37if2wbonkn49nf42nhar25
# Page number 82 starting
# Page 82 finished, next_token = b26v89c19zqg8o3fpdv8bg2wxk6cxvdmonocws4y2xm65
# Page number 83 starting
# Page 83 finished, next_token = b26v89c19zqg8o3fpdv8bg2wpyfbbtknj9tdejztq1uv1
# Page number 84 starting
# Page 84 finished, next_token = b26v89c19zqg8o3fpdv8be0vw2l6pzcqan2nnkx3eiut9
# Page number 85 starting
# Page 85 finished, next_token = b26v89c19zqg8o3fpdv8be0vohoxeba9uof3agjygwkfx
# Page number 86 starting
# Page 86 finished, next_token = b26v89c19zqg8o3fpdv8be0l55mkm6lud0uizueknbzp9
# Page number 87 starting
# Page 87 finished, next_token = b26v89c19zqg8o3fpdv8be0kz2pk85b5z0ig3ypvlgyv1
# Page number 88 starting
# Page 88 finished, next_token = b26v89c19zqg8o3fpdv8be0afrxamp4go30z8g0bjh5dp
# Page number 89 starting
# Page 89 finished, next_token = b26v89c19zqg8o3fpdv8be0a9oslp9165lcrfftbx16kd
# Page number 90 starting
# Page 90 finished, next_token = b26v89c19zqg8o3fpdv8bdzzouygz007rwxomnv00red9
# Page number 91 starting
# Page 91 finished, next_token = b26v89c19zqg8o3fpdv8bdzzirtvanvk9j23wq9ekc3nh
# Page number 92 starting
# Page 92 finished, next_token = b26v89c19zqg8o3fpdv8bdzzcp4g669g4haog590s5bwd
# Page number 93 starting
# Page 93 finished, next_token = b26v89c19zqg8o3fpdv8bdzorvxby2m8u7ti9dfxy22yl
# Page number 94 starting
# Page 94 finished, next_token = b26v89c19zqg8o3fpdv8bdzolt802e11js9qwkk9vat8d
# Page number 95 starting
# Page 95 finished, next_token = b26v89c19zqg8o3fpdv8bdze2gy46snfu250sitxktpx9
# Page number 96 starting
# Page 96 finished, next_token = b26v89c19zqg8o3fpdv8bdzdux3xlq42def9882vcyohp
# Page number 97 starting
# Page 97 finished, next_token = b26v89c19zqg8o3fpdv8bdz38j5pkvx5kdfzl5hyvykql
# Page number 98 starting
# Page 98 finished, next_token = b26v89c19zqg8o3fpdv8bdz2zeztdjxrtqedwy453d6kd
# Page number 99 starting
# Page 99 finished, next_token = b26v89c19zqg8o3fpdv8bdysbk4kkeqv10idxf4qbnddp
# Page number 100 starting
# Page 100 finished, next_token = b26v89c19zqg8o3fpdv8bdyhm6fj7puksb1o10gh5pj0d
# Page number 101 starting
# Page 101 finished, next_token = b26v89c19zqg8o3fpdv8bdyhd1mi5mjgoj07usr21yjjx
# Page number 102 starting
# Page 102 finished, next_token = b26v89c19zqg8o3fpdv8bdy6qpt4icg1xyr2z8ecw7qt9
# Page number 103 starting
# Page 103 finished, next_token = b26v89c19zqg8o3fpdv8bdy6kmgkk0dmzxtqa80r6s9z1
# Page number 104 starting
# Page 104 finished, next_token = b26v89c19zqg8o3fpdv8bbw5s8ea2tjwf4uatt45dmykd
# Page number 105 starting
# Page 105 finished, next_token = b26v89c19zqg8o3fpdv8bbw5m5p3m6m16y2e7oazo02nx
# Page number 106 starting
# Page 106 finished, next_token = b26v89c19zqg8o3fpdv8bbvv1bfkqz24xyj6ew9rd1ny5
# Page number 107 starting
# Page 107 finished, next_token = b26v89c19zqg8o3fpdv8bbvuqqct50grsfcuys1e3k1vh
# Page number 108 starting
# Page 108 finished, next_token = b26v89c19zqg8o3fpdv8bbvk4dwcsweqbsgjrsbxw1s3h
# Page number 109 starting
# Page 109 finished, next_token = b26v89c19zqg8o3fpdv8bbv9jhpulry4b8q4eynisv3wd
# Page number 110 starting
# Page 110 finished, next_token = b26v89c19zqg8o3fpdv8bbv9aemf69eny1jwdks1v1v25
# Page number 111 starting
# Page 111 finished, next_token = b26v89c19zqg8o3fpdv8bbuyo2l4b3zpzbnfx7e007v5p
# Page number 112 starting
# Page 112 finished, next_token = b26v89c19zqg8o3fpdv8bbuyghh8nbcixkjwd1vuv0epp
# Page number 113 starting
# Page 113 finished, next_token = b26v89c19zqg8o3fpdv8bbunx4c8la8j9id74wtx58k8t
# Page number 114 starting
# Page 114 finished, next_token = b26v89c19zqg8o3fpdv8bbunpl5c81fnfc3vijsj24l8d
# Page number 115 starting
# Page 115 finished, next_token = b26v89c19zqg8o3fpdv8bbud67t1ovp63a98sxrc8g8e5
# Page number 116 starting
# Page 116 finished, next_token = b26v89c19zqg8o3fpdv8bbucymwmyrwernavyr8m1frzx
# Page number 117 starting
# Page 117 finished, next_token = b26v89c19zqg8o3fpdv8bbu2asoacug4ny8zvwnizv725
# Page number 118 starting
# Page 118 finished, next_token = b26v89c19zqg8o3fpdv8bbu236hvpbv3a7y9oo6z5a83h
# Page number 119 starting
# Page 119 finished, next_token = b26v89c19zqg8o3fpdv8bbtribt44cr1jkksamdkg47zx
# Page number 120 starting
# Page 120 finished, next_token = b26v89c19zqg8o3fpdv8bbtr9950myo1ms28w5dgbe1dp
# Page number 121 starting
# Page 121 finished, next_token = b26v89c19zqg8o3fpdv8bbtgoent8y3w2m7isupeyrtdp
# Page number 122 starting
# Page 122 finished, next_token = b26v89c19zqg8o3fpdv8bbtgfbcrhgl5b77jo75ghsdq5
# Page number 123 starting
# Page 123 finished, next_token = b26v89c19zqg8o3fpdv8b9rffbbrwxpr1g7whjc4usha5
# Page number 124 starting
# Page 124 finished, next_token = b26v89c19zqg8o3fpdv8b9qu21wep2jdhbmlplq3xgdx9
# Page number 125 starting
# Page 125 finished, next_token = b26v89c19zqg8o3fpdv8b9pxlrlh6o9xbtdzuab2f4n0d
# Page number 126 starting
# Page 126 finished, next_token = b26v89c19zqg8o3fpdv8b9p1g1iqjggbgczavcbfkobjx
# Page number 127 starting
# Page 127 finished, next_token = b26v89c19zqg8o3fpdv8b9oqhkxk8zjam3oxzh15t4upp
# Page number 128 starting
# Page 128 finished, next_token = b26v89c19zqg8o3fpdv8b7mphljncosmnxvul1dontx19
# Page number 129 starting
# Page 129 finished, next_token = b26v89c19zqg8o3fpdv8b7mes6zjzn003zbbcacsq55dp
# Page number 130 starting
# Page 130 finished, next_token = b26v89c19zqg8o3fpdv8b7mej391wt9m3ae9lz35fvrlp
# Page number 131 starting
# Page 131 finished, next_token = b26v89c19zqg8o3fpdv8b7m3zqr7s4m29r6m7nnyz5xfh
# Page number 132 starting
# Page 132 finished, next_token = b26v89c19zqg8o3fpdv8b7m3s5fi5kjmuxjcyufe7d6yl
# Page number 133 starting
# Page 133 finished, next_token = b26v89c19zqg8o3fpdv8b7lt7b67wueokkg1hcmasnlvh
# Page number 134 starting
# Page 134 finished, next_token = b26v89c19zqg8o3fpdv8b7lszq9vdkqoqprqmuehmjszh
# Page number 135 starting
# Page 135 finished, next_token = b26v89c19zqg8o3fpdv8b7libwh16s8s64r9gonvyhksd
# Page number 136 starting
# Page 136 finished, next_token = b26v89c19zqg8o3fpdv8b7li49v570n55pqjg7ygol20t
# Page number 137 starting
# Page 137 finished, next_token = b26v89c19zqg8o3fpdv8b7l7hxu1w2iim9i2jgzkq9lrx
# Page number 138 starting
# Page 138 finished, next_token = b26v89c19zqg8o3fpdv8b7l7add3geach944h0zga7p19
# Page number 139 starting
# Page 139 finished, next_token = b26v89c19zqg8o3fpdv8b7kwr1i6l1u90cxpgfiaklksd
# Page number 140 starting
# Page 140 finished, next_token = b26v89c19zqg8o3fpdv8b7kwkxivw7mcjwu2dd14d5uv1
# Page number 141 starting
# Page 141 finished, next_token = b26v89c19zqg8o3fpdv8b7km03h2mp514pftre60oo77h
# Page number 142 starting
# Page 142 finished, next_token = b26v89c19zqg8o3fpdv8b7klu0rtz2g4kl3zvzn99q3y5
# Page number 143 starting
# Page 143 finished, next_token = b26v89c19zqg8o3fpdv8b7kb97sfdf7vc4yx1ncv56m4d
# Page number 144 starting
# Page 144 finished, next_token = b26v89c19zqg8o3fpdv8b7kb33sx487zm3rnuse1pfdrx
# Page number 145 starting
# Page 145 finished, next_token = b26v89c19zqg8o3fpdv8b7k0iae7k5kkyzhb58p2rsnlp
# Page number 146 starting
# Page 146 finished, next_token = b26v89c19zqg8o3fpdv8b7k0c71waf9ivpgzp0eqz9d31
# Page number 147 starting
# Page 147 finished, next_token = b26v89c19zqg8o3fpdv8b7k064rwezxbqwsbixg9n6m4d
# Page number 148 starting
# Page 148 finished, next_token = b26v89c19zqg8o3fpdv7wl7awj6ydc5387x4eyt0l6kcd
# Page number 149 starting
# Page 149 finished, next_token = b26v89c19zqg8o3fpdv7wl7aqgwu6cvq1i8i0n3xp66pp
# Page number 150 starting
# Page 150 finished, next_token = b26v89c19zqg8o3fpdv7wl7075hhvrpljyw3uekb9aw71
# Page number 151 starting
# Page 151 finished, next_token = b26v89c19zqg8o3fpdv7wl702kjuqx5ejhbay67lv1ugt
# Page number 152 starting
# Page 152 finished, next_token = b26v89c19zqg8o3fpdv7wl6zwi9vyj406mfaxzsm41jst
# Page number 153 starting
# Page 153 finished, next_token = b26v89c19zqg8o3fpdv7wl6pd7a257h47fp99fmsttda5
# Page number 154 starting
# Page 154 finished, next_token = b26v89c19zqg8o3fpdv7wl6p8lp93h17tzmv88e0myf0d
# Page number 155 starting
# Page 155 finished, next_token = b26v89c19zqg8o3fpdv7wl6p2jurnxyzzn2w5shmmjy4d
# Page number 156 starting
# Page 156 finished, next_token = b26v89c19zqg8o3fpdv7wl6ej9hon3hrrbuma99jti83h
# Page number 157 starting
# Page 157 finished, next_token = b26v89c19zqg8o3fpdv7wl6eeok5sf61qhyl8bwifdbi5
# Page number 158 starting
# Page 158 finished, next_token = b26v89c19zqg8o3fpdv7wl6ea4214u5ul6iobz6ev0vp9
# Page number 159 starting
# Page 159 finished, next_token = b26v89c19zqg8o3fpdv7wl63qtwnome4r5w7i9byicuwt
# Page number 160 starting
# Page 160 finished, next_token = b26v89c19zqg8o3fpdv7wl63ma90hsj5eumylsvvkazr1
# Page number 161 starting
# Page 161 finished, next_token = b26v89c19zqg8o3fpdv7wl63hpyj9d59jpn7gvfrufywt
# Page number 162 starting
# Page 162 finished, next_token = b26v89c19zqg8o3fpdv7wl5sydw38qfxzbous8uuvrkal
# Page number 163 starting
# Page 163 finished, next_token = b26v89c19zqg8o3fpdv7wl5sqss4awroxscx45adlhzlp
# Page number 164 starting
# Page 164 finished, next_token = b26v89c19zqg8o3fpdv7wl5i5zd785eq8z8i5nvmrn43h
# Page number 165 starting
# Page 165 finished, next_token = b26v89c19zqg8o3fpdv7wl5hzvdwiec3utq04zi4kpjel
# Page number 166 starting
# Page 166 finished, next_token = b26v89c19zqg8o3fpdv7wl57f1c4cj7yvxnbtbkp07b7h
# Page number 167 starting
# Page 167 finished, next_token = b26v89c19zqg8o3fpdv7wl577gnbypc69unpuir17l18d
# Page number 168 starting
# Page 168 finished, next_token = b26v89c19zqg8o3fpdv7wl4wmlqz34b1kqjdgvqbqlny5
# Page number 169 starting
# Page 169 finished, next_token = b26v89c19zqg8o3fpdv7wl4wf0n2btxou8uovodfox94t
# Page number 170 starting
# Page 170 finished, next_token = b26v89c19zqg8o3fpdv7wl4lu6dg6lftbtg4l2iasc22l
# Page number 171 starting
# Page 171 finished, next_token = b26v89c19zqg8o3fpdv7wl4ll3hqearfb2cy37qsu72wt
# Page number 172 starting
# Page 172 finished, next_token = b26v89c19zqg8o3fpdv7wj2kr789r51ziooeeh3xcbbst
# Page number 173 starting
# Page 173 finished, next_token = b26v89c19zqg8o3fpdv7wj2kjmbtxule7z78uo25t6j5p
# Page number 174 starting
# Page 174 finished, next_token = b26v89c19zqg8o3fpdv7wj29yrfdud3a2dan832oyna0t
# Page number 175 starting
# Page 175 finished, next_token = b26v89c19zqg8o3fpdv7wj29r5gkgzz84jxm430is61kt
# Page number 176 starting
# Page 176 finished, next_token = b26v89c19zqg8o3fpdv7wj1z6bmm75kquccxt5g6zif0d
# Page number 177 starting
# Page 177 finished, next_token = b26v89c19zqg8o3fpdv7wj1yyrdeg7xn1hew4lvqz1x8d
# Page number 178 starting
# Page 178 finished, next_token = b26v89c19zqg8o3fpdv7wj1occzlux7jtdgi5ns3yvgql
# Page number 179 starting
# Page 179 finished, next_token = b26v89c19zqg8o3fpdv7wj1dohwoi25oiubwix969p4l9
# Page number 180 starting
# Page 180 finished, next_token = b26v89c19zqg8o3fpdv7wj1dccxmgxh8e1mw4bnc156rh
# Page number 181 starting
# Page 181 finished, next_token = b26v89c19zqg8o3fpdv7wj12oh7kbqklw9zjmp92srf5p
# Page number 182 starting
# Page 182 finished, next_token = b26v89c19zqg8o3fpdv7wj0rz4czdo1z3groncogd61dp
# Page number 183 starting
# Page 183 finished, next_token = b26v89c19zqg8o3fpdv7wj0h9oqmse7jd0lyvjmv60n7h
# Page number 184 starting
# Page 184 finished, next_token = b26v89c19zqg8o3fpdv7wj0686wmtspr6uwh6ajyny3r1
# Page number 185 starting
# Page 185 finished, next_token = b26v89c19zqg8o3fpdv7wgx92ii347w9nketj080edwn1
# Page number 186 starting
# Page 186 finished, next_token = b26v89c19zqg8o3fpdv7wgwnd4yf1syopizkdst68g67x
# Page number 187 starting
# Page 187 finished, next_token = b26v89c19zqg8o3fpdv7wgwchobx2v1ifttkwlwm83zi5
# Page number 188 starting
# Page 188 finished, next_token = b26v89c19zqg8o3fpdv7wgw1nq4hbzwuuk276c41fi4cd
# Page number 189 starting
# Page 189 finished, next_token = b26v89c19zqg8o3fpdv7wgvr1bqu4den1udsrszv9ke4d
# Page number 190 starting
# Page 190 finished, next_token = b26v89c19zqg8o3fpdv7wgvgdg8ec2hf40ol6eftdgwal
# Page number 191 starting
# Page 191 finished, next_token = b26v89c19zqg8o3fpdv7wgvg1cr528xvj31q1vicitxfh
# Page number 192 starting
# Page 192 finished, next_token = b26v89c19zqg8o3fpdv7wgv5ggzo0dorr7s2ez659o5tp
# Page number 193 starting
# Page 193 finished, next_token = b26v89c19zqg8o3fpdv7wet4l3lokyfmey6cdngj9gayl
# Page number 194 starting
# Page 194 finished, next_token = b26v89c19zqg8o3fpdv7wet4dia4dqs4u4q7wnsyaq5j1
# Page number 195 starting
# Page 195 finished, next_token = b26v89c19zqg8o3fpdv7wet47e30sq5tg8vjd32oqyjr1
# Page number 196 starting
# Page 196 finished, next_token = b26v89c19zqg8o3fpdv7westo2ftirriw2w8lyz1u48sd
# Page number 197 starting
# Page 197 finished, next_token = b26v89c19zqg8o3fpdv7westghbyxk2twgstacayy4ry5
# Page number 198 starting
# Page 198 finished, next_token = b26v89c19zqg8o3fpdv7wesix646vg265wkjy6wel4xvh
# Page number 199 starting
# Page 199 finished, next_token = b26v89c19zqg8o3fpdv7wesir49k16h94nq6v316lhc3h
# Page number 200 starting
# Page 200 finished, next_token = b26v89c19zqg8o3fpdv7wes86a7qs4fb9s1mm6lnqwr5p
# Page number 201 starting
# Page 201 finished, next_token = b26v89c19zqg8o3fpdv7wes7x61zx3f9dcexhn61x7zb1
# Page number 202 starting
# Page 202 finished, next_token = b26v89c19zqg8o3fpdv7werxasyescomlcwkelamijjb1
# Page number 203 starting
# Page 203 finished, next_token = b26v89c19zqg8o3fpdv7werx1p8494ii8git97jq7cwvx
# Page number 204 starting
# Page 204 finished, next_token = b26v89c19zqg8o3fpdv7wermfcrhgrdysh066dbslpful
# Page number 205 starting
# Page 205 finished, next_token = b26v89c19zqg8o3fpdv7werbui2u69ig04kv9sk64dgn1
# Page number 206 starting
# Page 206 finished, next_token = b26v89c19zqg8o3fpdv7werbgv40ticnzyd34oxvcqbgd
# Page number 207 starting
# Page 207 finished, next_token = b26v89c19zqg8o3fpdv7wer0rh72b7y4611oxpel2u0e5
# Page number 208 starting
# Page 208 finished, next_token = b26v89c19zqg8o3fpdv7weqq232gbsenhd4hc9yn1rbst
# Page number 209 starting
# Page 209 finished, next_token = b26v89c19zqg8o3fpdv7weqfe6wyzt9u8xs5kxz6ue4ql
# Page number 210 starting
# Page 210 finished, next_token = b26v89c19zqg8o3fpdv7weqf3jx3qe9yf3z5wivu5ofi5
# Page number 211 starting
# Page 211 finished, next_token = b26v89c19zqg8o3fpdv7wcoe6lzmucostw38qle2o6mbh
# Page number 212 starting
# Page 212 finished, next_token = b26v89c19zqg8o3fpdv7wco3irz0xghc2z7t4dkh4k2v1
# Page number 213 starting
# Page 213 finished, next_token = b26v89c19zqg8o3fpdv7wco39ntdbumw6yd15qgqwql4t
# Page number 214 starting
# Page 214 finished, next_token = b26v89c19zqg8o3fpdv7wcnsot4ihlwecs5u4xynrjtdp
# Page number 215 starting
# Page 215 finished, next_token = b26v89c19zqg8o3fpdv7wcnsh7deqe3d049yxoj8g5da5
# Page number 216 starting
# Page 216 finished, next_token = b26v89c19zqg8o3fpdv7wcnhuvc2u0rjuo1zaxyx71t31
# Page number 217 starting
# Page 217 finished, next_token = b26v89c19zqg8o3fpdv7wcn78jiq89kawl53ap7bb25q5
# Page number 218 starting
# Page 218 finished, next_token = b26v89c19zqg8o3fpdv7wcn70xc8cp27bkorrykob1nr1
# Page number 219 starting
# Page 219 finished, next_token = b26v89c19zqg8o3fpdv7wcmwekvyj4cvxnyxij7dzdkzh
# Page number 220 starting
# Page 220 finished, next_token = b26v89c19zqg8o3fpdv7wcmw5hkp5r8xopc3nnh0wo8e5
# Page number 221 starting
# Page 221 finished, next_token = b26v89c19zqg8o3fpdv7wcmlkltn803njhxdmz999g3nh
# Page number 222 starting
# Page 222 finished, next_token = b26v89c19zqg8o3fpdv7wcmawrl7dkbqnla6j542v6wzh
# Page number 223 starting
# Page 223 finished, next_token = b26v89c19zqg8o3fpdv7wcmano2mg13ls5ll2hfklmhrx
# Page number 224 starting
# Page 224 finished, next_token = b26v89c19zqg8o3fpdv7wclzzss1owyl8m0pd738hbukd
# Page number 225 starting
# Page 225 finished, next_token = b26v89c19zqg8o3fpdv7wclpae7ycmhidz22q7k9068hp
# Page number 226 starting
# Page 226 finished, next_token = b26v89c19zqg8o3fpdv7wajo8wmvcc1f7k8bho1vfb14t
# Page number 227 starting
# Page 227 finished, next_token = b26v89c19zqg8o3fpdv7wajdghoss2352m0g789j5bo8t
# Page number 228 starting
# Page 228 finished, next_token = b26v89c19zqg8o3fpdv7waj2o2b5jizzqrv0vko3pqsfx
# Page number 229 starting
# Page 229 finished, next_token = b26v89c19zqg8o3fpdv7wairr32ay9ua2vncqa5u1x27x
# Page number 230 starting
# Page 230 finished, next_token = b26v89c19zqg8o3fpdv7wahvc91i149ii5cyqtmd3k6f1
# Page number 231 starting
# Page 231 finished, next_token = b26v89c19zqg8o3fpdv7wagyz075y0i5f44cqcj28ngxp
# Page number 232 starting
# Page 232 finished, next_token = b26v89c19zqg8o3fpdv7w8enb3su00qggb759c824fbel
# Page number 233 starting
# Page 233 finished, next_token = b26v89c19zqg8o3fpdv7w8ech7atdnm9rzbrb30zebjb1
# Page number 234 starting
# Page 234 finished, next_token = b26v89c19zqg8o3fpdv7w8ec6k3bqfp7wtddikmwg4kfx
# Page number 235 starting
# Page 235 finished, next_token = b26v89c19zqg8o3fpdv7w8e1k6k97rrow6l8lxtn7jou5
# Page number 236 starting
# Page 236 finished, next_token = b26v89c19zqg8o3fpdv7w8dqxvduyugiieosvw2b4q16l
# Page number 237 starting
# Page 237 finished, next_token = b26v89c19zqg8o3fpdv7w8dqrrm8snxccemohv50k3la5
# Page number 238 starting
# Page 238 finished, next_token = b26v89c19zqg8o3fpdv7w8dg6xcpxlsr5m9ou9cwkfn25
# Page number 239 starting
# Page 239 finished, next_token = b26v89c19zqg8o3fpdv7w8dfut0fqm9vlpsmf3p00i35p
# Page number 240 starting
# Page 240 finished, next_token = b26v89c19zqg8o3fpdv7w8d56ycxmd1tt1de569qmndrx
# Page number 241 starting
# Page 241 finished, next_token = b26v89c19zqg8o3fpdv7w8cum3gkqxegwqa0s6ra5pxtp
# Page number 242 starting
# Page 242 finished, next_token = b26v89c19zqg8o3fpdv7w8cuehwwwcc5cvgy49wt49m65
# Page number 243 starting
# Page 243 finished, next_token = b26v89c19zqg8o3fpdv7w8cjto340xru8l01xrvbc19x9
# Page number 244 starting
# Page 244 finished, next_token = b26v89c19zqg8o3fpdv7w8cjnkbbdqp7qd0z36roxxkzh
# Page number 245 starting
# Page 245 finished, next_token = b26v89c19zqg8o3fpdv7w8cjg09lndndyw0ixwdwyrekd
# Page number 246 starting
# Page 246 finished, next_token = b26v89c19zqg8o3fpdv7w8c8wnk9h7bdnc0sxgsz9elj1
# Page number 247 starting
# Page 247 finished, next_token = b26v89c19zqg8o3fpdv7w8c8nkohhb4d1uva9vrl368ot
# Page number 248 starting
# Page 248 finished, next_token = b26v89c19zqg8o3fpdv7w6a7s5da36isads3eza2bory5
# Page number 249 starting
# Page 249 finished, next_token = b26v89c19zqg8o3fpdv7w69x7bbhw8zyt9qt3k4w80lml
# Page number 250 starting
# Page 250 finished, next_token = b26v89c19zqg8o3fpdv7w69wzq7abmwqtj5sm5zvogkn1
# Page number 251 starting
# Page 251 finished, next_token = b26v89c19zqg8o3fpdv7w69mex0ckjvc7xyy0ep026ut9
# Page number 252 starting
# Page 252 finished, next_token = b26v89c19zqg8o3fpdv7w69m8tvqvwtpx0xp5fnfuygsd
# Page number 253 starting
# Page 253 finished, next_token = b26v89c19zqg8o3fpdv7w69m2r6g3fa56eh8rp9b6273x
# Page number 254 starting
# Page 254 finished, next_token = b26v89c19zqg8o3fpdv7w69bkx3ddc1edor6m75iy4jnh
# Page number 255 starting
# Page 255 finished, next_token = b26v89c19zqg8o3fpdv7w69bewirhzxy35a1ze6vjkepp
# Page number 256 starting
# Page 256 finished, next_token = b26v89c19zqg8o3fpdv7w69b8u1ao9vw453gd0at2829p
# Page number 257 starting
# Page 257 finished, next_token = b26v89c19zqg8o3fpdv7w690pgol0p5dxj4c6hiqkubul
# Page number 258 starting
# Page 258 finished, next_token = b26v89c19zqg8o3fpdv7w690hw7lig4vj2zt4ro46hr3x
# Page number 259 starting
# Page 259 finished, next_token = b26v89c19zqg8o3fpdv7w68pvih6bnmvhrru776pv508t
# Page number 260 starting
# Page 260 finished, next_token = b26v89c19zqg8o3fpdv7w68f7ne5rsyrvi5d9swku7r7h
# Page number 261 starting
# Page 261 finished, next_token = b26v89c19zqg8o3fpdv7w68eviu71k1u085530u2sd9q5
# Page number 262 starting
# Page 262 finished, next_token = b26v89c19zqg8o3fpdv7w68495b9wv2yrnrdw7f19frzx
# Page number 263 starting
# Page 263 finished, next_token = b26v89c19zqg8o3fpdv7w67tlb3aabznv16qzf3iiyb25
# Page number 264 starting
# Page 264 finished, next_token = b26v89c19zqg8o3fpdv7w67tc7cs71q35qjms8zvzbfy5
# Page number 265 starting
# Page 265 finished, next_token = b26v89c19zqg8o3fpdv7w67irbtcnjnd1t6ih7xc7wqd9
# Page number 266 starting
# Page 266 finished, next_token = b26v89c19zqg8o3fpdv7w67ii9s9olzps2q66cf6yuy65
# Page number 267 starting
# Page 267 finished, next_token = b26v89c19zqg8o3fpdv7w45hpu7yv57i585674u6rss59
# Page number 268 starting
# Page 268 finished, next_token = b26v89c19zqg8o3fpdv7w45hi8wfpra0gqtsac2i684fx
# Page number 269 starting
# Page 269 finished, next_token = b26v89c19zqg8o3fpdv7w456xgjzetdq6nkhw1in4ubgd
# Page number 270 starting
# Page 270 finished, next_token = b26v89c19zqg8o3fpdv7w456re2jniq97jqv0mvub9awt
# Page number 271 starting
# Page 271 finished, next_token = b26v89c19zqg8o3fpdv7w44w9j4omlij30o4x5wtacrjx
# Page number 272 starting
# Page 272 finished, next_token = b26v89c19zqg8o3fpdv7w44w1ynra9ke1vrxtto0gvfy5
# Page number 273 starting
# Page 273 finished, next_token = b26v89c19zqg8o3fpdv7w44lh58xg0mxyza28sur4yge5
# Page number 274 starting
# Page 274 finished, next_token = b26v89c19zqg8o3fpdv7w44lb2ywfknj1q81i6gm0hqil
# Page number 275 starting
# Page 275 finished, next_token = b26v89c19zqg8o3fpdv7w44l50heisvblfm47aluwl471
# Page number 276 starting
# Page 276 finished, next_token = b26v89c19zqg8o3fpdv7w44aloucna52lc8jbu3l2ru65
# Page number 277 starting
# Page 277 finished, next_token = b26v89c19zqg8o3fpdv7w44afmcitp6t7xjj6wo8ki9a5
# Page number 278 starting
# Page 278 finished, next_token = b26v89c19zqg8o3fpdv7w44ab17gveqm0oz8uo7k1d3st
# Page number 279 starting
# Page 279 finished, next_token = b26v89c19zqg8o3fpdv7w43zrqf2y3xgdu53t0k3iowal
# Page number 280 starting
# Page 280 finished, next_token = b26v89c19zqg8o3fpdv7w43zlokjccit3oiyx2x7dclfh
# Page number 281 starting
# Page 281 finished, next_token = b26v89c19zqg8o3fpdv7w43p3u1x1nnoflursu2423vjx
# Page number 282 starting
# Page 282 finished, next_token = b26v89c19zqg8o3fpdv7w43oxsmwzft18pnfs53qkal4t
# Page number 283 starting
# Page 283 finished, next_token = b26v89c19zqg8o3fpdv7w43ot79o66kx7jc56l6vaeohp
# Page number 284 starting
# Page 284 finished, next_token = b26v89c19zqg8o3fpdv7w43e9vuhahfwomngktdsvm2rh
# Page number 285 starting
# Page 285 finished, next_token = b26v89c19zqg8o3fpdv7w43e3tsbbuab9h2e6zfgb3a0t
# Page number 286 starting
# Page 286 finished, next_token = b26v89c19zqg8o3fpdv7w433hhyueu9ql97qju4psxgn1
# Page number 287 starting
# Page 287 finished, next_token = b26v89c19zqg8o3fpdv7w4335ck3g19fduh5nch77ilx9
# Page number 288 starting
# Page 288 finished, next_token = b26v89c19zqg8o3fpdv7w42seeiw8pvibcmflgxia0fp9
# Page number 289 starting
# Page 289 finished, next_token = b26v89c19zqg8o3fpdv7w20gnjg0801qlw6dpfp13sm7x
# Page number 290 starting
# Page 290 finished, next_token = b26v89c19zqg8o3fpdv7w1zkhtsqyuwnugezdvjxarv5p
# Page number 291 starting
# Page 291 finished, next_token = b26v89c19zqg8o3fpdv7w1z9jbxmwank5ygdy855fblod
# Page number 292 starting
# Page 292 finished, next_token = b26v89c19zqg8o3fpdv7w1yysgvri8g0tc0jjgejsuanx
# Page number 293 starting
# Page 293 finished, next_token = b26v89c19zqg8o3fpdv7w1yo4jo582b1ageapcmj2ofp9
# Page number 294 starting
# Page 294 finished, next_token = b26v89c19zqg8o3fpdv7w1ynty62qeojaabxl23wrjpml
# Page number 295 starting
# Page 295 finished, next_token = b26v89c19zqg8o3fpdv7w1yd931uuuhfuxz4ekr6ozxj1
# Page number 296 starting
# Page 296 finished, next_token = b26v89c19zqg8o3fpdv7w1yd1hxy2suvc1k50nwg4q9od
# Page number 297 starting
# Page 297 finished, next_token = b26v89c19zqg8o3fpdv7w1y2gp61ha07qn5xmc3nnnm2l
# Page number 298 starting
# Page 298 finished, next_token = b26v89c19zqg8o3fpdv7w1y2amgsuppxyjnq9o3ib3la5
# Page number 299 starting
# Page 299 finished, next_token = b26v89c19zqg8o3fpdv7hfld407hm4n10u2bs0qi6mut9
# Page number 300 starting
# Page 300 finished, next_token = b26v89c19zqg8o3fpdv7hflcxykopk4ykl929ya2gghvh
# Page number 301 starting
# Page 301 finished, next_token = b26v89c19zqg8o3fpdv7hflctepe2722x8gbgsjozylq5
# Page number 302 starting
# Page 302 finished, next_token = b26v89c19zqg8o3fpdv7hflcqbytrb3x4dj2f9zw49gn1
# Page number 303 starting
# Page 303 finished, next_token = b26v89c19zqg8o3fpdv7hfl28jsqd4ys5pewabed1ylbx
# Page number 304 starting
# Page 304 finished, next_token = b26v89c19zqg8o3fpdv7hfl25hp9srd1qmxiy4sa0tke5
# Page number 305 starting
# Page 305 finished, next_token = b26v89c19zqg8o3fpdv7hfl20zjgfij52t5tj00tc5qpp
# Page number 306 starting
# Page 306 finished, next_token = b26v89c19zqg8o3fpdv7hfl1xyanvhj739tagmhki0qrh
# Page number 307 starting
# Page 307 finished, next_token = b26v89c19zqg8o3fpdv7hfkrho46c7vmxgf0cszycj81p
# Page number 308 starting
# Page 308 finished, next_token = b26v89c19zqg8o3fpdv7hfkrg4fdy30tosm80fajhi7wd
# Page number 309 starting
# Page 309 finished, next_token = b26v89c19zqg8o3fpdv7hfkrd36i4bw11ak4ekygj6v0d
# Page number 310 starting
# Page 310 finished, next_token = b26v89c19zqg8o3fpdv7hfkr8iglod6upk7zrb5wnsbr1
# Page number 311 starting
# Page 311 finished, next_token = b26v89c19zqg8o3fpdv7hfkgp83p3rufio9uwx5u83ce5
# Page number 312 starting
# Page 312 finished, next_token = b26v89c19zqg8o3fpdv7hfkgkonvu0zxil7y7adrmm5bx
# Page number 313 starting
# Page 313 finished, next_token = b26v89c19zqg8o3fpdv7hfkgg4d97bryc01li2qfy8ku5
# Page number 314 starting
# Page 314 finished, next_token = b26v89c19zqg8o3fpdv7hfkgd21ue5n2sxb91nrhxmmil
# Page number 315 starting
# Page 315 finished, next_token = b26v89c19zqg8o3fpdv7hfk5ts4bzqtrdwhmbo9wdmg71
# Page number 316 starting
# Page 316 finished, next_token = b26v89c19zqg8o3fpdv7hfk5p81i7p6y9hbs8mrb44tx9
# Page number 317 starting
# Page 317 finished, next_token = b26v89c19zqg8o3fpdv7hfk5knyeob4z6drxjuyc1a73x
# Page number 318 starting
# Page 318 finished, next_token = b26v89c19zqg8o3fpdv7hfjv2uar55odkuu74bztq8w3h
# Page number 319 starting
# Page 319 finished, next_token = b26v89c19zqg8o3fpdv7hfjuws8oepy8p69zdk3iofzi5
# Page number 320 starting
# Page 320 finished, next_token = b26v89c19zqg8o3fpdv7hfjus85p7mvscjluqezyz3urh
# Page number 321 starting
# Page 321 finished, next_token = b26v89c19zqg8o3fpdv7hfjkaexdntsptxz31bw1kcyv1
# Page number 322 starting
# Page 322 finished, next_token = b26v89c19zqg8o3fpdv7hfjk5vhh47k7cxjqmuj7ku4xp
# Page number 323 starting
# Page 323 finished, next_token = b26v89c19zqg8o3fpdv7hfjk2syi5g5gzivl7tub88fi5
# Page number 324 starting
# Page 324 finished, next_token = b26v89c19zqg8o3fpdv7hfj9l0l109nhjfn9epf02ujy5
# Page number 325 starting
# Page 325 finished, next_token = b26v89c19zqg8o3fpdv7hfj9gh518lkz62udbh0pdjbel
# Page number 326 starting
# Page 326 finished, next_token = b26v89c19zqg8o3fpdv7hfj9by4kz3upimdxq6spyhm65
# Page number 327 starting
# Page 327 finished, next_token = b26v89c19zqg8o3fpdv7hfj98w0z1yr7a9imhhpvwk8sd
# Page number 328 starting
# Page 328 finished, next_token = b26v89c19zqg8o3fpdv7hfiysm24zooly15xutepqdmyl
# Page number 329 starting
# Page 329 finished, next_token = b26v89c19zqg8o3fpdv7hfiypktivayt8jeoqncmo25bx
# Page number 330 starting
# Page 330 finished, next_token = b26v89c19zqg8o3fpdv7hfiyggva3ley034nj4m20al4t
# Page number 331 starting
# Page 331 finished, next_token = b26v89c19zqg8o3fpdv7hfinu4ets8ohndsgs3coi00ot
# Page number 332 starting
# Page 332 finished, next_token = b26v89c19zqg8o3fpdv7hdgmyovseqrhabnsovzpidz0d
# Page number 333 starting
# Page 333 finished, next_token = b26v89c19zqg8o3fpdv7hdgmpl5dkko8mzgbc0j8sfud9
# Page number 334 starting
# Page 334 finished, next_token = b26v89c19zqg8o3fpdv7hdgc38p0i6rui2s0x7vzc4zul
# Page number 335 starting
# Page 335 finished, next_token = b26v89c19zqg8o3fpdv7hdgbx4poosdmfcpnxza7tmni5
# Page number 336 starting
# Page 336 finished, next_token = b26v89c19zqg8o3fpdv7hdg1asw6p7g36b8g4flf9faf1
# Page number 337 starting
# Page 337 finished, next_token = b26v89c19zqg8o3fpdv7hdg137kcs0kfmyqm1rnm8i3ct
# Page number 338 starting
# Page 338 finished, next_token = b26v89c19zqg8o3fpdv7hdfqidxuehy54gmx3efnbza7x
# Page number 339 starting
# Page 339 finished, next_token = b26v89c19zqg8o3fpdv7hdfqc9yp36fq70qt35muskqrh
# Page number 340 starting
# Page 340 finished, next_token = b26v89c19zqg8o3fpdv7hdffsy3yop2ywuarb29p9agzh
# Page number 341 starting
# Page 341 finished, next_token = b26v89c19zqg8o3fpdv7hdfflehhqja09hfg8wr5hsygt
# Page number 342 starting
# Page 342 finished, next_token = b26v89c19zqg8o3fpdv7hdf4z1tdxw35zgmefmtk25cvx
# Page number 343 starting
# Page 343 finished, next_token = b26v89c19zqg8o3fpdv7hdf4px83lg7ti4w63by3sqe7x
# Page number 344 starting
# Page 344 finished, next_token = b26v89c19zqg8o3fpdv7hdeu3jhphp5zlk9kygjgyr88t
# Page number 345 starting
# Page 345 finished, next_token = b26v89c19zqg8o3fpdv7hdejfp9jcs7m8uhl7quxk9yt9
# Page number 346 starting
# Page 346 finished, next_token = b26v89c19zqg8o3fpdv7hdej6lj2d5af0mbupv0y055rx
# Page number 347 starting
# Page 347 finished, next_token = b26v89c19zqg8o3fpdv7hde8k87qilwcvoi6dl1dl1wfx
# Page number 348 starting
# Page 348 finished, next_token = b26v89c19zqg8o3fpdv7hde8b3u7ye3r53fo7u2c5qcfx
# Page number 349 starting
# Page 349 finished, next_token = b26v89c19zqg8o3fpdv7hddxor5zu1s23rrgnp0lmt1tp
# Page number 350 starting
# Page 350 finished, next_token = b26v89c19zqg8o3fpdv7hbbwtbndlklybayc62z8qwdq5
# Page number 351 starting
# Page 351 finished, next_token = b26v89c19zqg8o3fpdv7hbbwk8rd0esfqgkrxuw2qe5q5
# Page number 352 starting
# Page 352 finished, next_token = b26v89c19zqg8o3fpdv7hbblwebkh38c80qcwzj4hxpj1
# Page number 353 starting
# Page 353 finished, next_token = b26v89c19zqg8o3fpdv7hbbb8ie4m9cuscyycssbdtugt
# Page number 354 starting
# Page 354 finished, next_token = b26v89c19zqg8o3fpdv7hbbauuse0bkbhud7xqpt7phtp
# Page number 355 starting
# Page 355 finished, next_token = b26v89c19zqg8o3fpdv7hbb02dx6osfu57hbs1mknsjgd
# Page number 356 starting
# Page 356 finished, next_token = b26v89c19zqg8o3fpdv7hbaej1slwy1iisfkzhv42pk71
# Page number 357 starting
# Page 357 finished, next_token = b26v89c19zqg8o3fpdv7hb97gdyp48fay6njlbyzbz4hp
# Page number 358 starting
# Page 358 finished, next_token = b26v89c19zqg8o3fpdv7h96ksikrewiogwscxgp3a90fx
# Page number 359 starting
# Page 359 finished, next_token = b26v89c19zqg8o3fpdv7h95zapi3wk9artqilk8ztuyrh
# Page number 360 starting
# Page 360 finished, next_token = b26v89c19zqg8o3fpdv7h95odq9adw23techzsj8xmoal
# Page number 361 starting
# Page 361 finished, next_token = b26v89c19zqg8o3fpdv7h95dlanxjo05x2bgeoxk6hm65
# Page number 362 starting
# Page 362 finished, next_token = b26v89c19zqg8o3fpdv7h952vxe0mk1q2w4epd60imtfh
# Page number 363 starting
# Page 363 finished, next_token = b26v89c19zqg8o3fpdv7h94s823k5xg11h96mv3hzd5kt
# Page number 364 starting
# Page 364 finished, next_token = b26v89c19zqg8o3fpdv7h94hh5clii7q15udv564vg60t
# Page number 365 starting
# Page 365 finished, next_token = b26v89c19zqg8o3fpdv7h72giokrko983378ena7qti7x
# Page number 366 starting
# Page 366 finished, next_token = b26v89c19zqg8o3fpdv7h72g81slwn7b6da3qkiudyovx
# Page number 367 starting
# Page 367 finished, next_token = b26v89c19zqg8o3fpdv7h725iob1jgvonhjex1bdot9q5
# Page number 368 starting
# Page 368 finished, next_token = b26v89c19zqg8o3fpdv7h71utaliviw4k8puyzlpg8igt
# Page number 369 starting
# Page 369 finished, next_token = b26v89c19zqg8o3fpdv7h71k3w1glyqkyqkbznabj9ksd
# Page number 370 starting
# Page 370 finished, next_token = b26v89c19zqg8o3fpdv7h71jrqmx77njfvmosjy4n7fy5
# Page number 371 starting
# Page 371 finished, next_token = b26v89c19zqg8o3fpdv7h7192campfd2igdsh9ywg0dq5
# Page number 372 starting
# Page 372 finished, next_token = b26v89c19zqg8o3fpdv7h70ybge9uwy1mczkizsej2irh
# Page number 373 starting
# Page 373 finished, next_token = b26v89c19zqg8o3fpdv7h70nnlbcj9nu361aji1efmu0t
# Page number 374 starting
# Page 374 finished, next_token = b26v89c19zqg8o3fpdv7h70czoyaz9v73idi95ohpi1rx
# Page number 375 starting
# Page 375 finished, next_token = b26v89c19zqg8o3fpdv7h70cp1qmv6ynkj65d6v1bebnh
# Page number 376 starting
# Page 376 finished, next_token = b26v89c19zqg8o3fpdv7h70216vlm3p0zy88q33g9r799
# Page number 377 starting
# Page 377 finished, next_token = b26v89c19zqg8o3fpdv7h6zrdbkta6hbw627ggow3y5j1
# Page number 378 starting
# Page 378 finished, next_token = b26v89c19zqg8o3fpdv7h6zr2p7xfkf10ed80pd0dgtj1
# Page number 379 starting
# Page 379 finished, next_token = b26v89c19zqg8o3fpdv7h4xq7ac32lg3t132auvluycn1
# Page number 380 starting
# Page 380 finished, next_token = b26v89c19zqg8o3fpdv7h4xpzpnh68m85jnpvqxjtmtml
# Page number 381 starting
# Page 381 finished, next_token = b26v89c19zqg8o3fpdv7h4xfdck0dclw4l4a098zxlhml
# Page number 382 starting
# Page 382 finished, next_token = b26v89c19zqg8o3fpdv7h4x4ny7pvpofuuzd026ttg67x
# Page number 383 starting
# Page 383 finished, next_token = b26v89c19zqg8o3fpdv7h4wu02a3iclm8r4e002tmeykd
# Page number 384 starting
# Page 384 finished, next_token = b26v89c19zqg8o3fpdv7h4wtpfpfw453zbigg9nkjqcfx
# Page number 385 starting
# Page 385 finished, next_token = b26v89c19zqg8o3fpdv7h4wj1ku872vahpnxn6qjtlzst
# Page number 386 starting
# Page 386 finished, next_token = b26v89c19zqg8o3fpdv7h4w8dowo08rugjg6i21x66n3x
# Page number 387 starting
# Page 387 finished, next_token = b26v89c19zqg8o3fpdv7h4w8336penw7snv4cdpqcjxbx
# Page number 388 starting
# Page 388 finished, next_token = b26v89c19zqg8o3fpdv7h4vxgq349x8oicigbvp7c88zh
# Page number 389 starting
# Page 389 finished, next_token = b26v89c19zqg8o3fpdv7h4vx93wngsdlhaidw88la5ksd
# Page number 390 starting
# Page 390 finished, next_token = b26v89c19zqg8o3fpdv7h4vml99bub0jpyhvy67fvcuwt
# Page number 391 starting
# Page 391 finished, next_token = b26v89c19zqg8o3fpdv7h4vbubv54ok9ozxevz1wasyv1
# Page number 392 starting
# Page 392 finished, next_token = b26v89c19zqg8o3fpdv7h4v10fkkdq6ngbonb5o3sfd6l
# Page number 393 starting
# Page 393 finished, next_token = b26v89c19zqg8o3fpdv7h2szucmdxzyqg3baxip4mt4sd
# Page number 394 starting
# Page 394 finished, next_token = b26v89c19zqg8o3fpdv7h2s3urlk8luz7tnt4fs8grfjx
# Page number 395 starting
# Page 395 finished, next_token = b26v89c19zqg8o3fpdv7h2r73ssvflryiyf79jjgljekd
# Page number 396 starting
# Page 396 finished, next_token = b26v89c19zqg8o3fpdv7h2qawl60asnlsfdaimt0j5jst
# Page number 397 starting
# Page 397 finished, next_token = b26v89c19zqg8o3fpdv7h0o9p0nupxngbjj5q2uzgwscd
# Page number 398 starting
# Page 398 finished, next_token = b26v89c19zqg8o3fpdv7h0nogawddd8snenntn26fuz5p
# Page number 399 starting
# Page 399 finished, next_token = b26v89c19zqg8o3fpdv7h0ndpdpryck7ctxj90qx5si2l
# Page number 400 starting
# Page 400 finished, next_token = b26v89c19zqg8o3fpdv7h0ndd9lams13va4usxrti64cd
# Page number 401 starting
# Page 401 finished, next_token = b26v89c19zqg8o3fpdv7h0n2nw3lwzm281q0j47vuz5od
# Page number 402 starting
# Page 402 finished, next_token = b26v89c19zqg8o3fpdv7h0mryi6k5qfrc0omsif3ikf3x
# Page number 403 starting
# Page 403 finished, next_token = b26v89c19zqg8o3fpdv7h0mhc4vdq2zowkneh22mtilx9
# Page number 404 starting
# Page 404 finished, next_token = b26v89c19zqg8o3fpdv7h0mh31ryaeyls2sxik2hgctx9
# Page number 405 starting
# Page 405 finished, next_token = b26v89c19zqg8o3fpdv7h0m6gooc1f4r01hvx4sm4w48t
# Page number 406 starting
# Page 406 finished, next_token = b26v89c19zqg8o3fpdv7h0m67l5r41cpazcl4727jciv1
# Page number 407 starting
# Page 407 finished, next_token = b26v89c19zqg8o3fpdv7h0lvmqgpsh2qgoc0uae60wa65
# Page number 408 starting
# Page 408 finished, next_token = b26v89c19zqg8o3fpdv7h0lvf3v2efnk4q5bhlftg0k1p
# Page number 409 starting
# Page 409 finished, next_token = b26v89c19zqg8o3fpdv7h0lkssgvblrzdv899lp4us0ot
# Page number 410 starting
# Page 410 finished, next_token = b26v89c19zqg8o3fpdv7h0lkl6psmo5v6x7v9k9z6karh
# Page number 411 starting
# Page 411 finished, next_token = b26v89c19zqg8o3fpdv7gyjjpsouv0sa5c9l3eg6w10fx
# Page number 412 starting
# Page 412 finished, next_token = b26v89c19zqg8o3fpdv7gyjjjopgxz7zs57vu2yxywdx9
# Page number 413 starting
# Page 413 finished, next_token = b26v89c19zqg8o3fpdv7gyj8xcvtj7a40ocpg9srslh8d
# Page number 414 starting
# Page 414 finished, next_token = b26v89c19zqg8o3fpdv7gyiycietpuevz4xzd748u1ojh
# Page number 415 starting
# Page 415 finished, next_token = b26v89c19zqg8o3fpdv7gyiy3e17uuahba8re5e78an3x
# Page number 416 starting
# Page 416 finished, next_token = b26v89c19zqg8o3fpdv7gyinh15hqj0icft7kfoyl8d4t
# Page number 417 starting
# Page 417 finished, next_token = b26v89c19zqg8o3fpdv7gyin6f0511z1nax764zaz52f1
# Page number 418 starting
# Page 418 finished, next_token = b26v89c19zqg8o3fpdv7gyick1wjv3cvttojgm6kkfczh
# Page number 419 starting
# Page 419 finished, next_token = b26v89c19zqg8o3fpdv7gyi1xpga0gcr43w28h5xr24xp
# Page number 420 starting
# Page 420 finished, next_token = b26v89c19zqg8o3fpdv7gyi1n2vlc8qw1um9t4r6ei3r1
# Page number 421 starting
# Page 421 finished, next_token = b26v89c19zqg8o3fpdv7gyhqz8fnf3itpp7bmyw4plnr1
# Page number 422 starting
# Page 422 finished, next_token = b26v89c19zqg8o3fpdv7gyhg6rsc5o7a09ni7bzokfvjx
# Page number 423 starting
# Page 423 finished, next_token = b26v89c19zqg8o3fpdv7gyh5ectxp6t2757trzg2anptp
# Page number 424 starting
# Page 424 finished, next_token = b26v89c19zqg8o3fpdv7gygunf88y2qmpzqzcp1cvm2rh
# Page number 425 starting
# Page 425 finished, next_token = b26v89c19zqg8o3fpdv7gwetng1ps0xdiocg8cj8ri5q5
# Page number 426 starting
# Page 426 finished, next_token = b26v89c19zqg8o3fpdv7gweitjrgx4lxkvqxqp1dcs519
# Page number 427 starting
# Page 427 finished, next_token = b26v89c19zqg8o3fpdv7gwe813ygnl3rgg2cfsdih1ny5
# Page number 428 starting
# Page 428 finished, next_token = b26v89c19zqg8o3fpdv7gwdxa655jabxuecf4rsh2c1h9
# Page number 429 starting
# Page 429 finished, next_token = b26v89c19zqg8o3fpdv7gwdmhrtvwi3b8h6kamsixq8ot
# Page number 430 starting
# Page 430 finished, next_token = b26v89c19zqg8o3fpdv7gwdbpbluhjrebt7f1kkstgkn1
# Page number 431 starting
# Page 431 finished, next_token = b26v89c19zqg8o3fpdv7gwd0ww0n1rbyef0g3c30rqq2l
# Page number 432 starting
# Page 432 finished, next_token = b26v89c19zqg8o3fpdv7gwcpzy9j0tn7vu0mp76oc79fh
# Page number 433 starting
# Page 433 finished, next_token = b26v89c19zqg8o3fpdv7gwc4gli36h5g1ls3uzi0xao3h
# Page number 434 starting
# Page 434 finished, next_token = b26v89c19zqg8o3fpdv729yip3sgke2954e2mmj97iq9p
# Page number 435 starting
# Page 435 finished, next_token = b26v89c19zqg8o3fpdv729xwv65q2zglmw7sbvmguclfh
# Page number 436 starting
# Page 436 finished, next_token = b26v89c19zqg8o3fpdv729xbevpd30msapml9de37ukcd
# Page number 437 starting
# Page 437 finished, next_token = b26v89c19zqg8o3fpdv729x0jeg14098bamb85r6qfji5
# Page number 438 starting
# Page 438 finished, next_token = b26v89c19zqg8o3fpdv729wptzo3uxkruin7ltidor9fh
# Page number 439 starting
# Page 439 finished, next_token = b26v89c19zqg8o3fpdv727uox1y77d8x001pwpr6k87el
# Page number 440 starting
# Page 440 finished, next_token = b26v89c19zqg8o3fpdv727ue7oodhjufv1d1gee219qwt
# Page number 441 starting
# Page 441 finished, next_token = b26v89c19zqg8o3fpdv727udykxs5wxrqz30cbc7yw3nh
# Page number 442 starting
# Page 442 finished, next_token = b26v89c19zqg8o3fpdv727u3c8hbtsytge3lnhd9s3w59
# Page number 443 starting
# Page 443 finished, next_token = b26v89c19zqg8o3fpdv727u333onrpt1l16e5tqsil665
# Page number 444 starting
# Page 444 finished, next_token = b26v89c19zqg8o3fpdv727tsi8zld9laemyg495ryfdkt
# Page number 445 starting
# Page 445 finished, next_token = b26v89c19zqg8o3fpdv727thufehvcz7ibbn2t2wacosd
# Page number 446 starting
# Page 446 finished, next_token = b26v89c19zqg8o3fpdv727thmu2r6zbdbly26txi3hjlp
# Page number 447 starting
# Page 447 finished, next_token = b26v89c19zqg8o3fpdv727t73hdjazk73jimt3axipth9
# Page number 448 starting
# Page 448 finished, next_token = b26v89c19zqg8o3fpdv727t6xeghuobsw6qomr7o9mflp
# Page number 449 starting
# Page 449 finished, next_token = b26v89c19zqg8o3fpdv727t6pu6y7zcl2theddmw5rzb1
# Page number 450 starting
# Page 450 finished, next_token = b26v89c19zqg8o3fpdv727sw3ggl6yrnw2kxiy6g5nrst
# Page number 451 starting
# Page 451 finished, next_token = b26v89c19zqg8o3fpdv727sle3tjdktoqah85dhw9dnct
# Page number 452 starting
# Page 452 finished, next_token = b26v89c19zqg8o3fpdv727saq83jd8zfostng0xizq3y5
# Page number 453 starting
# Page 453 finished, next_token = b26v89c19zqg8o3fpdv727sae2wl8sr5eqkizetzurkal
# Page number 454 starting
# Page 454 finished, next_token = b26v89c19zqg8o3fpdv727rzonpr4c2wv0hwmfaapc8e5
# Page number 455 starting
# Page 455 finished, next_token = b26v89c19zqg8o3fpdv725pyq7kztyz3trwg7ad5k4dj1
# Page number 456 starting
# Page 456 finished, next_token = b26v89c19zqg8o3fpdv725po0tg8hmht8e3j37pyi5cal
# Page number 457 starting
# Page 457 finished, next_token = b26v89c19zqg8o3fpdv725pdbgdyzj4xnw5nkx0nuir99
# Page number 458 starting
# Page 458 finished, next_token = b26v89c19zqg8o3fpdv725pd0ugnrnkgij82any4xmhrx
# Page number 459 starting
# Page 459 finished, next_token = b26v89c19zqg8o3fpdv725p2ehkjl23l2u5grfs3ffy4d
# Page number 460 starting
# Page 460 finished, next_token = b26v89c19zqg8o3fpdv725p26uyrvgvukroz321ywdpbx
# Page number 461 starting
# Page 461 finished, next_token = b26v89c19zqg8o3fpdv725orm272uggwbhltkjk0kly7x
# Page number 462 starting
# Page 462 finished, next_token = b26v89c19zqg8o3fpdv725orhi44pyan6x8jp23nzhxml
# Page number 463 starting
# Page 463 finished, next_token = b26v89c19zqg8o3fpdv725ogy61t1xepnxvl9kcrbikxp
# Page number 464 starting
# Page 464 finished, next_token = b26v89c19zqg8o3fpdv725ogqk31uc7p9yhafa1usm7b1
# Page number 465 starting
# Page 465 finished, next_token = b26v89c19zqg8o3fpdv725o65qo93ku881z0explw15z1
# Page number 466 starting
# Page 466 finished, next_token = b26v89c19zqg8o3fpdv725o5znz0gv2cjpq9s1s9hjc71
# Page number 467 starting
# Page 467 finished, next_token = b26v89c19zqg8o3fpdv725o5tkexdzw337nne3ogkl9x9
# ...
# Page number 2864 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2865 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2866 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2867 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2868 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2869 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2870 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2871 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2872 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2873 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2874 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2875 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2876 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2877 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2878 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2879 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2880 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2881 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2882 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2883 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2884 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2885 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2886 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2887 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2888 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2889 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2890 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2891 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2892 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2893 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2894 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2895 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2896 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2897 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2898 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2899 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2900 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2901 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2902 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2903 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2904 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2905 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2906 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2907 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2908 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2909 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2910 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2911 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2912 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2913 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2914 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2915 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2916 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2917 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2918 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2919 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2920 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2921 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2922 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2923 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2924 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2925 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2926 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2927 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2928 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2929 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2930 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2931 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2932 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2933 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2934 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2935 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2936 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2937 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2938 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2939 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2940 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2941 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2942 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2943 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2944 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2945 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2946 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2947 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2948 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2949 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2950 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2951 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2952 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2953 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2954 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2955 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2956 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2957 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2958 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2959 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2960 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2961 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2962 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2963 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2964 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2965 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2966 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2967 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2968 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2969 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2970 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2971 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2972 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2973 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2974 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2975 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2976 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2977 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2978 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2979 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2980 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2981 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2982 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2983 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2984 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2985 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2986 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2987 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2988 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2989 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2990 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2991 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2992 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2993 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2994 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2995 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2996 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2997 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2998 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 2999 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3000 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3001 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3002 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3003 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3004 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3005 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3006 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3007 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3008 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3009 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3010 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3011 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3012 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3013 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3014 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3015 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3016 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3017 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3018 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3019 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3020 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3021 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3022 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3023 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3024 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3025 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3026 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3027 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3028 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3029 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3030 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3031 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3032 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3033 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3034 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3035 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3036 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3037 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3038 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3039 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3040 starting
# Page {num_pages} finished. All tweets for this query collected.
# Page number 3041 starting

# %%
df.to_csv("retweets.csv")

# %%
# Merge all files in temp/ if necessary
all_files = glob.glob(os.path.join("temp/", "*.csv"))     

df_from_each_file = (pd.read_csv(f) for f in all_files)
concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)
del concatenated_df["Unnamed: 0"]

# %%
concatenated_df
# Out:
#                    author_id                 created_at                   id  \
# 0        1417148229053988879  2021-10-07 00:12:23+00:00  1445904805852033026
# 1        1376715806235561984  2021-10-07 00:11:27+00:00  1445904569066786817
# 2        1441084185653829644  2021-10-07 00:12:12+00:00  1445904758074654720
# 3        1386666107994583045  2021-10-07 00:11:20+00:00  1445904541019475969
# 4                  423895213  2021-10-07 00:11:17+00:00  1445904527010369536
# ...                      ...                        ...                  ...
# 1145702           2678455944  2021-10-07 00:00:08+00:00  1445901720026976256
# 1145703            633330070  2021-10-07 00:00:05+00:00  1445901707251175427
# 1145704  1051634101390856193  2021-10-07 00:00:04+00:00  1445901705695088640
# 1145705            316918405  2021-10-07 00:00:02+00:00  1445901696979308550
# 1145706  1058014331420450817  2021-10-07 00:00:00+00:00  1445901686007078913
#
#                                                       text  \
# 0        RT @MarcosRogerio: O relator informou que colo...
# 1        RT @MarcosRogerio: O relator informou que colo...
# 2        RT @MarcosRogerio: O relator informou que colo...
# 3        RT @MarcosRogerio: O relator informou que colo...
# 4        RT @MarcosRogerio: O relator informou que colo...
# ...                                                    ...
# 1145702  RT @GFiuza_Oficial: Mais uma: Sofia, 17 anos, ...
# 1145703  RT @monicabergamo: O "kit Covid", pacote de re...
# 1145704  RT @simoneregazio: Meu amor vcs aplaudiram reu...
# 1145705  RT @BarbeariaPoian: A Suécia interrompe o uso ...
# 1145706  RT @AiltonBenedito: Infectados são capazes de ...
#
#         referenced_tweets_type  referenced_tweets_id  \
# 0                    retweeted   1445890361688313856
# 1                    retweeted   1445890361688313856
# 2                    retweeted   1445890361688313856
# 3                    retweeted   1445890361688313856
# 4                    retweeted   1445890361688313856
# ...                        ...                   ...
# 1145702              retweeted   1444772527084130304
# 1145703              retweeted   1445884696320266241
# 1145704              retweeted   1445883224710946820
# 1145705              retweeted   1445734811453247489
# 1145706              retweeted   1445730455966334976
#
#                  author_created_at  \
# 0        2021-07-19 15:44:25+00:00
# 1        2021-03-30 02:00:22+00:00
# 2        2021-09-23 16:57:17+00:00
# 3        2021-04-26 12:59:10+00:00
# 4        2011-11-29 02:21:10+00:00
# ...                            ...
# 1145702  2014-07-25 02:35:43+00:00
# 1145703  2012-07-12 00:23:54+00:00
# 1145704  2018-10-15 00:41:22+00:00
# 1145705  2011-06-14 04:48:00+00:00
# 1145706  2018-11-01 15:14:08+00:00
#
#                                              author_name  author_username  \
# 0                                                    EaS      EaS33130022
# 1                                          Filipe Vianna    _DireitaUnida
# 2                                       EmersonFernandez  Emerson79311981
# 3                                          Sérgio Morais   SergioMorais38
# 4                                            Edmir Silva      EdmirSilva1
# ...                                                  ...              ...
# 1145702  MANOEL MOURA ............................BRAZIL     MANOELMOURA1
# 1145703                              Luciana de Oliveira      LubraulioDe
# 1145704                                     Lalo Proenca      LaloProenca
# 1145705             Thiago🇧🇷 BOLSONARO.🔰 🪂 FORÇA E AÇÃO!       Thiago_CIR
# 1145706                          João Aristóteles 🔰🗡🇧🇷🗡🔰   AristotelesVia
#
#          referenced_tweets_author_id referenced_tweets_created_at  \
# 0                          160895960    2021-10-06 23:15:00+00:00
# 1                          160895960    2021-10-06 23:15:00+00:00
# 2                          160895960    2021-10-06 23:15:00+00:00
# 3                          160895960    2021-10-06 23:15:00+00:00
# 4                          160895960    2021-10-06 23:15:00+00:00
# ...                              ...                          ...
# 1145702                   2804949532    2021-10-03 21:13:07+00:00
# 1145703                     58951368    2021-10-06 22:52:29+00:00
# 1145704           771574989195575302    2021-10-06 22:46:38+00:00
# 1145705                   2802207875    2021-10-06 12:56:54+00:00
# 1145706                    342403919    2021-10-06 12:39:35+00:00
#
#                                     referenced_tweets_text  \
# 0        O relator informou que colocará o presidente d...
# 1        O relator informou que colocará o presidente d...
# 2        O relator informou que colocará o presidente d...
# 3        O relator informou que colocará o presidente d...
# 4        O relator informou que colocará o presidente d...
# ...                                                    ...
# 1145702  Mais uma: Sofia, 17 anos, estudante saudável, ...
# 1145703  O "kit Covid", pacote de remédios ineficazes c...
# 1145704  Meu amor vcs aplaudiram reunião  com Amado Bat...
# 1145705  A Suécia interrompe o uso de 💉💉💉 da covid  par...
# 1145706  Infectados são capazes de gerar anticorpos con...
#
#         referenced_tweets_author_created_at referenced_tweets_author_name  \
# 0                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 1                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 2                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 3                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 4                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# ...                                     ...                           ...
# 1145702           2014-10-04 13:20:53+00:00               Guilherme Fiuza
# 1145703           2009-07-21 22:55:27+00:00                Mônica Bergamo
# 1145704           2016-09-02 05:06:27+00:00              Simone Regazio 🚩
# 1145705           2014-10-03 16:22:22+00:00       Verdades e Nada Mais 🔸️
# 1145706           2011-07-25 23:37:38+00:00             🇧🇷Ailton Benedito
#
#         referenced_tweets_author_username
# 0                           MarcosRogerio
# 1                           MarcosRogerio
# 2                           MarcosRogerio
# 3                           MarcosRogerio
# 4                           MarcosRogerio
# ...                                   ...
# 1145702                    GFiuza_Oficial
# 1145703                     monicabergamo
# 1145704                     simoneregazio
# 1145705                    BarbeariaPoian
# 1145706                    AiltonBenedito
#
# [1145707 rows x 15 columns]

# %%
concatenated_df.to_csv("retweets.csv")
